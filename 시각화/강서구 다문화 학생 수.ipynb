# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

stu = pd.read_csv('다문화가정학생.csv', thousands=',')
stu
# Out:
#         기간   자치구  초등학교 총계  초등학교 국제결혼가정  초등학교 외국인가정  중학교 총계  중학교 국제결혼가정  \
# 0   2021.0    합계    13093         8932        4161    4049        2839
# 1      NaN   종로구      157          115          42      72          55
# 2      NaN    중구      245          151          94      78          53
# 3      NaN   용산구      402          255         147     133          87
# 4      NaN   성동구      449          333         116     130         100
# 5      NaN   광진구      503          295         208     132          92
# 6      NaN  동대문구      496          357         139     160         117
# 7      NaN   중랑구      592          431         161     176         139
# 8      NaN   성북구      564          458         106     177         145
# 9      NaN   강북구      408          369          39      97          89
# 10     NaN   도봉구      401          374          27     100          86
# 11     NaN   노원구      413          382          31     148         134
# ...

# %%
stu1 = stu.fillna('2021')
stu2 = stu1.drop(index=0, axis=0)
stu2
# Out:
#       기간   자치구  초등학교 총계  초등학교 국제결혼가정  초등학교 외국인가정  중학교 총계  중학교 국제결혼가정  \
# 1   2021   종로구      157          115          42      72          55
# 2   2021    중구      245          151          94      78          53
# 3   2021   용산구      402          255         147     133          87
# 4   2021   성동구      449          333         116     130         100
# 5   2021   광진구      503          295         208     132          92
# 6   2021  동대문구      496          357         139     160         117
# 7   2021   중랑구      592          431         161     176         139
# 8   2021   성북구      564          458         106     177         145
# 9   2021   강북구      408          369          39      97          89
# 10  2021   도봉구      401          374          27     100          86
# 11  2021   노원구      413          382          31     148         134
# 12  2021   은평구      607          555          52     229         189
# 13  2021  서대문구      312          276          36      99          87
# ...

# %%
data_sum = []
for i in range(len(stu)):
    if "강서구" in stu.iloc[i]["자치구"]:
        data_sum.append(stu.iloc[i])
data_sum_df = pd.DataFrame(data_sum)

data_sum_df
g_stu = data_sum_df.fillna('2021')

g_stu
# Out:
#       기간  자치구  초등학교 총계  초등학교 국제결혼가정  초등학교 외국인가정  중학교 총계  중학교 국제결혼가정  \
# 16  2021  강서구      682          591          91     155         144
#
#     중학교 외국인가정  고등학교 총계  고등학교 국제결혼가정  고등학교 외국인가정
# 16         11      101           89          12

# %%
import numpy as np
x = np.arange(3)
school = ['초등학교 총계', '중학교 총계', '고등학교 총계']
values = [682, 155, 101]
plt.title('2021년 강서구 학령별 다문화 학생 수')
plt.bar(x, values, color=['pink', 'y', 'blue'])
plt.xticks(x, school)

plt.show()
# Out:
# /Users/songjeong-won/miniforge3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/songjeong-won/miniforge3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/songjeong-won/miniforge3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/songjeong-won/miniforge3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 g_stu1.info()
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'info'
